# %%
import sys
sys.path.append('..')
from compiler.LOTree import *
from compiler.Graph import random_tree

# %%
# tree = test()
import random
random.seed(1334)
t = random_tree(10)
lotree = LOTree(0)
build_optimal_linear(t.head,lotree)
# Out:
# 0 1
# 0 2
# 0 3
# 2 4
# 0 5
# 5 6
# 5 7
# 4 8
# 2 9
# in build optimal for node 0
# in build optimal for node 1
# in build optimal for node 2
# in build optimal for node 4
# in build optimal for node 8
# added edge 4 8
# in build optimal for node 9
# added edge 2 9
# added edge 2 4
# in build optimal for node 3
# in build optimal for node 5
# in build optimal for node 6
# in build optimal for node 7
# added edge 5 6
# added edge 5 7
# added edge 0 1
# added edge 0 3
# added edge 0 2
# added edge 0 5
# (<compiler.LOTree.LOTree at 0x72625d5b94d0>, 6)

# %%
pcvl.pdisplay(lotree.circuit, recursive=True)

# %%
expand = [(t.head,0)]
while expand:
    vertex,depth = expand.pop()
    print(" "*(4*(depth-1))+("|---" if depth > 0 else "")+str(vertex.value))
    for child in vertex.children:
        expand.append((child, depth+1))
# Out:
# 0
# |---5
#     |---7
#     |---6
# |---3
# |---2
#     |---9
#     |---4
#         |---8
# |---1

# %%
lotree.tree.head.children
# Out:
# [<compiler.Graph.TreeNode at 0x72625d5b98d0>,
#  <compiler.Graph.TreeNode at 0x72625c1ae190>,
#  <compiler.Graph.TreeNode at 0x72625d5b9a90>,
#  <compiler.Graph.TreeNode at 0x72625cb10710>]

# %%
expand = [(lotree.tree.head,0)]
while expand:
    vertex,depth = expand.pop()
    print(" "*(4*(depth-1))+("|---" if depth > 0 else "")+str(vertex.value))
    for child in reversed(vertex.children):
        expand.append((child, depth+1))
# Out:
# 0
# |---1
# |---3
# |---2
#     |---9
#     |---4
#         |---8
# |---5
#     |---6
#     |---7

# %%
lotree.vertex_pos_map
# Out:
# {0: 44, 1: 10, 3: 16, 2: 20, 5: 46}

# %%
circ = pcvl.Circuit(0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 circ = pcvl.Circuit(0)
#
# File ~/miniconda3/envs/perceval/lib/python3.11/site-packages/perceval/components/linear_circuit.py:293, in Circuit.__init__(self, m, name)
#     292 def __init__(self, m: int, name: str = None):
# --> 293     assert m > 0, "invalid size"
#     294     super().__init__(m, name)
#     295     self._components = []
#
# AssertionError: invalid size
